# %%
import json
import logging
import time
from datetime import datetime
from os import mkdir
from os.path import isdir

import cloudscraper
import requests
from bs4 import BeautifulSoup

# %%
logging.basicConfig(
	format="{asctime} - {levelname} - {message}",
	datefmt="%Y-%m-%d %H:%M",
	level=logging.DEBUG,
	style="{"
)

# %%
# modelVersions.id	modelVersions.name	modelVersions.description	modelVersions.createdAt	modelVersions.downloadUrl
# modelVersions.trainedWords	modelVersions.files.sizeKb

# gencost.quantity	gencost.size	gencost.base
# gencost.addresource	gencost.creatortip	gencost.civitaitip

# remix.workflow	remix.model	num_remix.addresources
# remix_addresourcestype	remix_prompt	remix_triggerwords	remix_negprompt

# stats.downloadCount	stats.favoriteCount	stats.commentCount	stats.ratingCount	stats.rating
# modelEarlyaccess	earlyaccess.donation	earlyaccess.timeframe
# gencost.popularity	gencost.sampler


api = 'https://civitai.com/api'
limit = 10
cut_off_date = datetime(2025, 1, 1)

# %%
def processModel(model):
	logging.info(f'Processing model {model["id"]}')
	with open(f"./model_api/{model['id']}.json", 'w', encoding='utf-8') as f:
		json.dump(model, f, ensure_ascii=False, indent=4)
	# logging.debug(json.dumps(model, indent=4))
	# id	name	description	type	nsfw	tags	mode	creator.username	creator.image
	data = {
		"model.id": model['id'],
		"model.name": model['name'],
		"model.description": model['description'],
		"model.type": model['type'],
		"model.nsfw": model['nsfw'],
		"model.nsfwLevel": model['nsfwLevel'],
		"model.tags": ", ".join(model['tags']),
		"model.mode": model.get('mode', None),
		"model.creator.username": model['creator']['username'],
		"model.creator.image": model['creator']['image'],
		"model.stats.downloadCount": model['stats']['downloadCount'],
		"model.stats.favoriteCount": model['stats']['favoriteCount'],
		"model.stats.commentCount": model['stats']['commentCount'],
		"model.stats.ratingCount": model['stats']['ratingCount'],
		"model.stats.rating": model['stats']['rating'],
		"model.stats.thumbsUpCount": model['stats']['thumbsUpCount'],
		"model.stats.thumbsDownCount": model['stats']['thumbsDownCount'],
		"model.stats.tippedAmountCount": model['stats']['tippedAmountCount'],

		"model.availability": model['availability'],
		"model.allowNoCredit": model['allowNoCredit'],
		"model.allowCommercialUse": ", ".join(model['allowCommercialUse']) if "allowCommercialUse" in model else None,
		"model.allowDerivatives": model['allowDerivatives'],
		"model.allowDifferentLicense": model['allowDifferentLicense'],
		"model.minor": model['minor'],
		"model.poi": model['poi'],
		"model.cosmetic": model['cosmetic'],
		"model.supportsGeneration": model['supportsGeneration'],
	}
	versions = []
	modelData = getModelData(model['id'])
	for modelversion in model['modelVersions']:
		file = modelversion['files'][0]
		version = {
			"modelVersion.id": modelversion['id'],
			"modelVersion.name": modelversion['name'],
			"modelVersion.description": modelversion.get('description', None),
			"modelVersion.createdAt": modelversion['createdAt'],
			"modelVersion.downloadUrl": modelversion['downloadUrl'],
			"modelVersion.trainedWords": ", ".join(
				modelversion['trainedWords']) if "trainedWords" in modelversion else None,
			"modelVersion.files.sizeKb": file['sizeKB'],

			"modelVersion.versionBaseModel": modelversion['baseModel'],
			"modelVersion.versionBaseModelType": modelversion[
				'baseModelType'] if "baseModelType" in modelversion else None,
			"modelVersion.versionStatus": modelversion['status'],
			"modelVersion.versionAvailability": modelversion['availability'],
			"modelVersion.versionNsfwLevel": modelversion['nsfwLevel'],
			"modelVersion.versionFileName": file['name'],
			"modelVersion.versionFileType": file['type'],
		}
		version_data = getModelVersion(model['id'], modelversion['id'])
		version.update(version_data)
		if modelversion['id'] in modelData:
			version.update(modelData[modelversion['id']])
		versions.append(version)
	data['modelVersions'] = versions
	logging.info(json.dumps(data, indent=4))
	with open(f"./result/{model['id']}.json", 'w', encoding='utf-8') as f:
		json.dump(data, f, ensure_ascii=False, indent=4)

# %%
def getModelData(model_id):
	logging.info(f'Getting model data for {model_id}')
	url = f'https://civitai.com/models/{model_id}'
	res = cloudscraper.create_scraper().get(url)
	soup = BeautifulSoup(res.content, 'lxml')
	script = json.loads(soup.find("script", {"id": "__NEXT_DATA__"}).text)
	with open(f"./model/{model_id}.json", 'w', encoding='utf-8') as f:
		json.dump(script, f, ensure_ascii=False, indent=4)
	versionData = {}
	queries = script['props']['pageProps']['trpcState']['json']['queries']
	for query in queries:
		if "getById" not in query['queryHash']:
			continue
		state = query['state']['data']
		if state['id'] != model_id:
			continue
		rank = state['rank']
		for modelVersion in state['modelVersions']:
			if modelVersion['earlyAccessDeadline']:
				donationGoal = getDonationGoal(modelVersion['id'])
			else:
				donationGoal = {"goalAmount": None, "total": None}
			data = {
				"modelVersion.GenerationCountAllTime": modelVersion['rank']['generationCountAllTime'],
				"modelVersion.DownloadCountAllTime": modelVersion['rank']['downloadCountAllTime'],
				"modelVersion.RatingCountAllTime": modelVersion['rank']['ratingCountAllTime'],
				"modelVersion.RatingAllTime": modelVersion['rank']['ratingAllTime'],
				"modelVersion.ThumbsUpCountAllTime": modelVersion['rank']['thumbsUpCountAllTime'],
				"modelVersion.ThumbsDownCountAllTime": modelVersion['rank']['thumbsDownCountAllTime'],
				"modelVersion.name": modelVersion['name'],
				"modelVersion.id": modelVersion['id'],
				"modelVersion.modelId": modelVersion['modelId'],
				"model.downloadCountAllTime": rank['downloadCountAllTime'],
				"model.favoriteCountAllTime": rank['favoriteCountAllTime'],
				"model.thumbsUpCountAllTime": rank['thumbsUpCountAllTime'],
				"model.thumbsDownCountAllTime": rank['thumbsDownCountAllTime'],
				"model.commentCountAllTime": rank['commentCountAllTime'],
				"model.ratingCountAllTime": rank['ratingCountAllTime'],
				"model.ratingAllTime": rank['ratingAllTime'],
				"model.tippedAmountCountAllTime": rank['tippedAmountCountAllTime'],
				"model.imageCountAllTime": rank['imageCountAllTime'],
				"model.collectedCountAllTime": rank['collectedCountAllTime'],
				"model.generationCountAllTime": rank['generationCountAllTime'],
				"model.earlyAccessDeadlineModel": state['earlyAccessDeadline'],
				"modelVersion.earlyAccessEndsAt": modelVersion['earlyAccessEndsAt'],

				"modelVersion.earlyAccessDeadline": modelVersion['earlyAccessDeadline'],
				"modelVersion.donationGoalAmount": donationGoal['goalAmount'],
				"modelVersion.donationGoalTotal": donationGoal['total'],
			}
			if modelVersion['earlyAccessConfig']:
				data["modelVersion.earlyAccessConfig.timeframe"] = modelVersion['earlyAccessConfig']['timeframe']
				data["modelVersion.earlyAccessConfig.donationGoal"] = modelVersion['earlyAccessConfig'][
					'donationGoal'] if "donationGoal" in modelVersion['earlyAccessConfig'] else None
				data["modelVersion.earlyAccessConfig.downloadPrice"] = modelVersion['earlyAccessConfig'][
					'downloadPrice']
				data["modelVersion.earlyAccessConfig.donationGoalId"] = modelVersion['earlyAccessConfig'][
					'donationGoalId'] if "donationGoalId" in modelVersion['earlyAccessConfig'] else None
				data["modelVersion.earlyAccessConfig.generationPrice"] = modelVersion['earlyAccessConfig'][
					'generationPrice']
				data["modelVersion.earlyAccessConfig.chargeForDownload"] = modelVersion['earlyAccessConfig'][
					'chargeForDownload']
				# data["modelVersion.earlyAccessConfig.originalTimeframe"] = modelVersion['earlyAccessConfig'][
				#	'originalTimeframe']
				data["modelVersion.earlyAccessConfig.originalTimeframe"]   = modelVersion['earlyAccessConfig'].get('originalTimeframe')  
				data["modelVersion.earlyAccessConfig.chargeForGeneration"] = modelVersion['earlyAccessConfig'][
					'chargeForGeneration']
				data["modelVersion.earlyAccessConfig.donationGoalEnabled"] = modelVersion['earlyAccessConfig'][
					'donationGoalEnabled']
				data["modelVersion.earlyAccessConfig.originalPublishedAt"] = modelVersion['earlyAccessConfig'][
					'originalPublishedAt']
				data["modelVersion.earlyAccessConfig.generationTrialLimit"] = modelVersion['earlyAccessConfig'][
					'generationTrialLimit']
			versionData[modelVersion['id']] = data
	return versionData

# %%
def getDonationGoal(modelVersionId):
	logging.info(f'Getting donation goal for model version {modelVersionId}')
	url = f'https://civitai.com/api/trpc/modelVersion.donationGoals?input={{"json":{{"id":{modelVersionId},"authed":true}}}}'
	res = getRes(url).json()
	data = res['result']['data']['json'][0]
	return {"goalAmount": data['goalAmount'], "total": data['total']}

# %%
def getModel(model_id):
	logging.info(f'Getting model {model_id}')
	url = f'{api}/v1/models/{model_id}'
	res = getRes(url).json()
	processModel(res)

# %%
def getModelVersion(model_id, version_id):
	logging.info(f'Getting model {model_id} version {version_id}')
	url = f'{api}/v1/model-versions/{version_id}'
	res = getRes(url).json()
	with open(f'./model-version/{model_id}_{version_id}.json', 'w', encoding='utf-8') as f:
		json.dump(res, f, ensure_ascii=False, indent=4)
	# logging.debug(json.dumps(res, indent=4))
	stats = res['stats']
	data = {
		"modelVersion.id": res['id'],
		"modelVersion.name": res['name'],
		"modelVersion.createdAt": res['createdAt'],
		"modelVersion.updatedAt": res['updatedAt'],
		"modelVersion.status": res['status'],
		"modelVersion.publishedAt": res['publishedAt'],
		"modelVersion.trainedWords": ", ".join(res['trainedWords']),
		"modelVersion.trainingStatus": res['trainingStatus'],
		"modelVersion.trainingDetails": res['trainingDetails'],
		"modelVersion.baseModel": res['baseModel'],
		"modelVersion.baseModelType": res['baseModelType'],
		"modelVersion.earlyAccessEndsAt": res['earlyAccessEndsAt'],
		"modelVersion.description": res['description'],
		"modelVersion.stats.downloadCount": stats['downloadCount'],
		"modelVersion.stats.ratingCount": stats['ratingCount'],
		"modelVersion.stats.rating": stats['rating'],
		"modelVersion.stats.thumbsUpCount": stats['thumbsUpCount'],
		"model.name": res['model']['name'],
		"model.type": res['model']['type'],
		"images": []
	}
	for image in res['images']:
		image_data = {
			"image.url": image['url'],
			"image.nsfwLevel": image['nsfwLevel'],
			"image.type": image['type'],
			"image.metadata.size": image['metadata']['size'],
			"image.prompt": image['meta']['prompt'],
			"image.sampler": image['meta']['sampler'],
			"image.steps": image['meta']['steps'],
			"image.cfgScale": image['meta']['cfgScale'],
			"image.negativePrompt": image['meta']['negativePrompt'] if "negativePrompt" in image['meta'] else None,
		}
		data["images"].append(image_data)
	# logging.debug(json.dumps(data, indent=4))
	return data

# %%
def getAllModels():
	logging.info('Getting all models')
	url = f'{api}/v1/models?sort=Newest&limit={limit}'
	should_continue = True
	while should_continue:
		res = getRes(url).json()
		for model in res['items']:
			processModel(model)
			if len(model['modelVersions']) > 0:
				first_model_version = model['modelVersions'][0]
				if datetime.strptime(first_model_version['publishedAt'], '%Y-%m-%dT%H:%M:%S.%fZ') < cut_off_date:
					should_continue = False
					break
		url = res['metadata']['nextPage']
		if url is None:
			should_continue = False

# %%
def main():
	logo()
	for x in ['model_api', 'model-version', 'image', 'result', 'model']:
		if not isdir(x):
			mkdir(x)
	# getAllModels()
	getModel('297100')
	getModel('654541')

# %%
def logo():
	print(r"""
    _________  .__        .__   __      _____   .___ 
    \_   ___ \ |__|___  __|__|_/  |_   /  _  \  |   |
    /    \  \/ |  |\  \/ /|  |\   __\ /  /_\  \ |   |
    \     \____|  | \   / |  | |  |  /    |    \|   |
     \______  /|__|  \_/  |__| |__|  \____|__  /|___|
            \/                               \/      
==========================================================
      API based CivitAI Scraper by Muhammad Hassan 
          (https://github.com/evilgenius786)
==========================================================
[+] API Based
[+] Scrapes tips and donation info
[+] Scrapes stats like remix and downloads count
[+] Scrapes early access information
[+] Scrapes resource information
[+] Scrapes model versions
__________________________________________________________
""")
	time.sleep(0.1)

# %%
def getRes(url, params=None):
	logging.info(f'Getting response from {url}')
	return requests.get(url, params=params)

# %%
if __name__ == '__main__':
	main()
# Out:
# 2025-04-16 20:41 - INFO - Getting model 297100
# 2025-04-16 20:41 - INFO - Getting response from https://civitai.com/api/v1/models/297100
# 2025-04-16 20:41 - DEBUG - Starting new HTTPS connection (1): civitai.com:443
#     _________  .__        .__   __      _____   .___
#     \_   ___ \ |__|___  __|__|_/  |_   /  _  \  |   |
#     /    \  \/ |  |\  \/ /|  |\   __\ /  /_\  \ |   |
#     \     \____|  | \   / |  | |  |  /    |    \|   |
#      \______  /|__|  \_/  |__| |__|  \____|__  /|___|
#             \/                               \/
# ==========================================================
#       API based CivitAI Scraper by Muhammad Hassan
#           (https://github.com/evilgenius786)
# ==========================================================
# [+] API Based
# [+] Scrapes tips and donation info
# [+] Scrapes stats like remix and downloads count
# [+] Scrapes early access information
# [+] Scrapes resource information
# [+] Scrapes model versions
# __________________________________________________________
# 2025-04-16 20:41 - DEBUG - https://civitai.com:443 "GET /api/v1/models/297100 HTTP/1.1" 200 None
# 2025-04-16 20:41 - INFO - Processing model 297100
# 2025-04-16 20:41 - INFO - Getting model data for 297100
# 2025-04-16 20:41 - DEBUG - Starting new HTTPS connection (1): civitai.com:443
# 2025-04-16 20:41 - DEBUG - https://civitai.com:443 "GET /models/297100 HTTP/1.1" 200 None
# 2025-04-16 20:41 - INFO - Getting model 297100 version 333803
# 2025-04-16 20:41 - INFO - Getting response from https://civitai.com/api/v1/model-versions/333803
# 2025-04-16 20:41 - DEBUG - Starting new HTTPS connection (1): civitai.com:443
# 2025-04-16 20:41 - DEBUG - https://civitai.com:443 "GET /api/v1/model-versions/333803 HTTP/1.1" 200 None
# 2025-04-16 20:41 - INFO - {
#     "model.id": 297100,
#     "model.name": "Sawa Okita/\u6c96\u7530 \u7d17\u7fbd (Tari Tari) LoRA | 3 Outfits",
#     "model.description": "<h3 id=\"i-have-a-form-for-requests-now-check-it-out-if-you-want-to-request-a-character\"><a target=\"_blank\" rel=\"ugc\" href=\"https://docs.google.com/forms/d/e/1FAIpQLScl88t__7YLUtDYZjWlxIPIarH5uyl2bI85FlWyJatQOIAt6A/viewform\">I have a form for requests; check it out if you want to request a character.</a></h3><p>Sawa Okita from Tari Tari. Trained on NAI. Tested at 0.8-1.0 strength.</p><p>Trigger word is \"<strong><span style=\"color:rgb(250, 176, 5)\">okitasawa</span></strong>\" and \"<strong><span style=\"color:rgb(250, 176, 5)\">low twintails</span></strong>\" is required.</p><ul><li><p>Add \"<strong><span style=\"color:#fa5252\">hat, choker, frilled dress, black skirt, bare shoulders</span></strong>\" for her regular appearance.</p></li><li><p>Add \"<strong><span style=\"color:#fd7e14\">brown jacket, red necktie, yellow sweater vest, blue skirt, pantyhose</span></strong>\" for her school uniform.</p></li><li><p>Add \"<strong><span style=\"color:#82c91e\">white shirt, short sleeves, red necktie, blue skirt</span></strong>\" for her alternate school uniform.</p></li></ul><p>A request from the form. Check out my <a target=\"_blank\" rel=\"ugc\" href=\"https://discord.gg/uk5qHgE62B\"><strong>Discord</strong></a> if you want to chat about video games (or yell at me about requests.)</p>",
#     "model.type": "LORA",
#     "model.nsfw": false,
#     "model.nsfwLevel": 7,
#     "model.tags": "anime, character, female, woman, tari tari",
#     "model.mode": null,
#     "model.creator.username": "novowels",
#     "model.creator.image": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/c1520b6b-1c16-4284-befb-c7880b67e477/width=96/novowels.jpeg",
#     "model.stats.downloadCount": 721,
#     "model.stats.favoriteCount": 0,
#     "model.stats.commentCount": 1,
#     "model.stats.ratingCount": 0,
#     "model.stats.rating": 0,
#     "model.stats.thumbsUpCount": 158,
#     "model.stats.thumbsDownCount": 0,
#     "model.stats.tippedAmountCount": 0,
#     "model.availability": "Public",
#     "model.allowNoCredit": true,
#     "model.allowCommercialUse": "Image, RentCivit",
#     "model.allowDerivatives": true,
#     "model.allowDifferentLicense": true,
#     "model.minor": false,
#     "model.poi": false,
#     "model.cosmetic": null,
#     "model.supportsGeneration": true,
#     "modelVersions": [
#         {
#             "modelVersion.id": 333803,
#             "modelVersion.name": "v1",
#             "modelVersion.description": "<p>Not sure if she had more outfits, so let me know if I missed one...</p>",
#             "modelVersion.createdAt": "2024-02-08T01:07:15.617Z",
#             "modelVersion.downloadUrl": "https://civitai.com/api/download/models/333803",
#             "modelVersion.trainedWords": "okitasawa, low twintails, hat, choker, frilled dress, black skirt, bare shoulders, cleavage, brown jacket, red necktie, yellow sweater vest, blue skirt, pantyhose, white shirt, short sleeves, red necktie, blue skirt",
#             "modelVersion.files.sizeKb": 36982.1171875,
#             "modelVersion.versionBaseModel": "SD 1.5",
#             "modelVersion.versionBaseModelType": null,
#             "modelVersion.versionStatus": "Published",
#             "modelVersion.versionAvailability": "Public",
#             "modelVersion.versionNsfwLevel": 7,
#             "modelVersion.versionFileName": "okitasawa-nvwls-v1.safetensors",
#             "modelVersion.versionFileType": "Model",
#             "modelVersion.updatedAt": "2024-02-08T01:13:46.021Z",
#             "modelVersion.status": "Published",
#             "modelVersion.publishedAt": "2024-02-08T01:13:46.020Z",
#             "modelVersion.trainingStatus": null,
#             "modelVersion.trainingDetails": null,
#             "modelVersion.baseModel": "SD 1.5",
#             "modelVersion.baseModelType": null,
#             "modelVersion.earlyAccessEndsAt": null,
#             "modelVersion.stats.downloadCount": 721,
#             "modelVersion.stats.ratingCount": 102,
#             "modelVersion.stats.rating": 5,
#             "modelVersion.stats.thumbsUpCount": 158,
#             "model.name": "Sawa Okita/\u6c96\u7530 \u7d17\u7fbd (Tari Tari) LoRA | 3 Outfits",
#             "model.type": "LORA",
#             "images": [
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/775f7e5a-e8b6-4a50-abd4-4bd3506d3617/width=1024/6385408.jpeg",
#                     "image.nsfwLevel": 2,
#                     "image.type": "image",
#                     "image.metadata.size": 2108409,
#                     "image.prompt": "masterpiece, best quality, <lora:okitasawa-nvwls-v1-000009:0.9> okitasawa, low twintails, hat, choker, cleavage, frilled dress, black skirt, bare shoulders, :D, large breasts, upper body, cityscape, blue sky, looking at viewer",
#                     "image.sampler": "DPM++ 2M Karras",
#                     "image.steps": 22,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "(worst quality, low quality:1.4), fcNeg, text, watermark"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/dbcf8e8f-24b8-4fe3-b602-48dfb359f2b4/width=1024/6385393.jpeg",
#                     "image.nsfwLevel": 1,
#                     "image.type": "image",
#                     "image.metadata.size": 1596662,
#                     "image.prompt": "masterpiece, best quality, <lora:okitasawa-nvwls-v1-000009:0.9> okitasawa, low twintails, brown jacket, red necktie, yellow sweater vest, blue skirt, pantyhose, cowboy shot, looking at viewer, large breasts, smile, hallway, hand on hip",
#                     "image.sampler": "DPM++ 2M Karras",
#                     "image.steps": 22,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "(worst quality, low quality:1.4), fcNeg, text, watermark"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/150bb2fa-ffef-4576-983c-a2005a829884/width=1024/6385398.jpeg",
#                     "image.nsfwLevel": 1,
#                     "image.type": "image",
#                     "image.metadata.size": 1452264,
#                     "image.prompt": "masterpiece, best quality, <lora:okitasawa-nvwls-v1-000009:0.9> okitasawa, low twintails, white shirt, short sleeves, red necktie, blue skirt, blush, pout, looking away, cowboy shot, hallway",
#                     "image.sampler": "DPM++ 2M Karras",
#                     "image.steps": 23,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "(worst quality, low quality:1.4), fcNeg, text, watermark"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/9a45f62d-5ed3-4959-bb78-d75c90cdfa30/width=1024/6385391.jpeg",
#                     "image.nsfwLevel": 2,
#                     "image.type": "image",
#                     "image.metadata.size": 1775850,
#                     "image.prompt": "masterpiece, best quality, <lora:okitasawa-nvwls-v1-000009:0.9> okitasawa, low twintails, hat, choker, cleavage, frilled dress, black skirt, bare shoulders, large breasts, riding horse, horseback riding, sky, clouds, smile, looking at viewer",
#                     "image.sampler": "DPM++ 2M Karras",
#                     "image.steps": 22,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "(worst quality, low quality:1.4), fcNeg, text, watermark"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/8a7cf736-8dc1-44bd-94aa-ce3be996da31/width=1024/6385487.jpeg",
#                     "image.nsfwLevel": 1,
#                     "image.type": "image",
#                     "image.metadata.size": 1935580,
#                     "image.prompt": "masterpiece, best quality, <lora:okitasawa-nvwls-v1-000009:0.9> okitasawa, low twintails, brown jacket, red necktie, yellow sweater vest, blue skirt, pantyhose, sitting, desk, chair, library, smile",
#                     "image.sampler": "DPM++ 2M Karras",
#                     "image.steps": 20,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "(worst quality, low quality:1.4), fcNeg, text, watermark"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/8bd53490-5b13-48c6-9460-9e467b9a2155/width=1024/6385401.jpeg",
#                     "image.nsfwLevel": 1,
#                     "image.type": "image",
#                     "image.metadata.size": 1892828,
#                     "image.prompt": "masterpiece, best quality, <lora:okitasawa-nvwls-v1-000009:0.9> okitasawa, low twintails, white shirt, short sleeves, red necktie, blue skirt, black socks, sneakers, jumping, raised arms, :D, sky, clouds, street",
#                     "image.sampler": "DPM++ 2M Karras",
#                     "image.steps": 22,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "(worst quality, low quality:1.4), fcNeg, text, watermark"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/545b4664-cb70-49eb-bdc5-5b8e1434c50c/width=1024/6385399.jpeg",
#                     "image.nsfwLevel": 2,
#                     "image.type": "image",
#                     "image.metadata.size": 1934761,
#                     "image.prompt": "masterpiece, best quality, <lora:okitasawa-nvwls-v1-000009:0.9> okitasawa, low twintails, hat, choker, cleavage, frilled dress, black skirt, bare shoulders, large breasts, closed eyes, smiling, garden, sitting, table, chair, teapot",
#                     "image.sampler": "DPM++ 2M Karras",
#                     "image.steps": 22,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "(worst quality, low quality:1.4), fcNeg, text, watermark"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/a622d530-db8b-4271-93fa-a8ef85de7bc7/width=1024/6385392.jpeg",
#                     "image.nsfwLevel": 1,
#                     "image.type": "image",
#                     "image.metadata.size": 1897478,
#                     "image.prompt": "masterpiece, best quality, <lora:okitasawa-nvwls-v1-000009:0.9> okitasawa, low twintails, brown jacket, red necktie, yellow sweater vest, blue skirt, pantyhose, socks, sneakers, stairs, schoolhouse, outdoors, blue sky, clouds, smile",
#                     "image.sampler": "DPM++ 2M Karras",
#                     "image.steps": 21,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "(worst quality, low quality:1.4), fcNeg, text, watermark"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/5b149c7a-cfde-49f4-96d0-1c88f2f7de5d/width=1024/6385402.jpeg",
#                     "image.nsfwLevel": 1,
#                     "image.type": "image",
#                     "image.metadata.size": 1661760,
#                     "image.prompt": "masterpiece, best quality, <lora:okitasawa-nvwls-v1-000009:0.9> okitasawa, low twintails, white shirt, short sleeves, red necktie, blue skirt, crossed arms, looking at viewer, head tilt, from below, hallway",
#                     "image.sampler": "DPM++ 2M Karras",
#                     "image.steps": 22,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "(worst quality, low quality:1.4), fcNeg, text, watermark"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/9b5771d2-72b9-4e8d-b038-c328b76adea1/width=1024/6385410.jpeg",
#                     "image.nsfwLevel": 2,
#                     "image.type": "image",
#                     "image.metadata.size": 1800450,
#                     "image.prompt": "masterpiece, best quality, <lora:okitasawa-nvwls-v1-000009:0.9> okitasawa, low twintails, hat, choker, cleavage, frilled dress, black skirt, bare shoulders, :D, large breasts, cowboy shot, smile, looking at viewer, beach, walking, blue sky",
#                     "image.sampler": "DPM++ 2M Karras",
#                     "image.steps": 22,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "(worst quality, low quality:1.4), fcNeg, text, watermark"
#                 }
#             ],
#             "modelVersion.GenerationCountAllTime": 1279,
#             "modelVersion.DownloadCountAllTime": 721,
#             "modelVersion.RatingCountAllTime": 102,
#             "modelVersion.RatingAllTime": 5,
#             "modelVersion.ThumbsUpCountAllTime": 158,
#             "modelVersion.ThumbsDownCountAllTime": 0,
#             "modelVersion.modelId": 297100,
#             "model.downloadCountAllTime": 721,
#             "model.favoriteCountAllTime": 129,
#             "model.thumbsUpCountAllTime": 158,
#             "model.thumbsDownCountAllTime": 0,
#             "model.commentCountAllTime": 1,
#             "model.ratingCountAllTime": 102,
#             "model.ratingAllTime": 5,
#             "model.tippedAmountCountAllTime": 0,
#             "model.imageCountAllTime": 29,
#             "model.collectedCountAllTime": 17,
#             "model.generationCountAllTime": 1279,
#             "model.earlyAccessDeadlineModel": null,
#             "modelVersion.earlyAccessDeadline": null,
#             "modelVersion.donationGoalAmount": null,
#             "modelVersion.donationGoalTotal": null
#         }
#     ]
# }
# 2025-04-16 20:41 - INFO - Getting model 654541
# 2025-04-16 20:41 - INFO - Getting response from https://civitai.com/api/v1/models/654541
# 2025-04-16 20:41 - DEBUG - Starting new HTTPS connection (1): civitai.com:443
# 2025-04-16 20:41 - DEBUG - https://civitai.com:443 "GET /api/v1/models/654541 HTTP/1.1" 200 None
# 2025-04-16 20:41 - INFO - Processing model 654541
# 2025-04-16 20:41 - INFO - Getting model data for 654541
# 2025-04-16 20:41 - DEBUG - Starting new HTTPS connection (1): civitai.com:443
# 2025-04-16 20:41 - DEBUG - https://civitai.com:443 "GET /models/654541 HTTP/1.1" 200 None
# 2025-04-16 20:41 - INFO - Getting donation goal for model version 1643268
# 2025-04-16 20:41 - INFO - Getting response from https://civitai.com/api/trpc/modelVersion.donationGoals?input={"json":{"id":1643268,"authed":true}}
# 2025-04-16 20:41 - DEBUG - Starting new HTTPS connection (1): civitai.com:443
# 2025-04-16 20:41 - DEBUG - https://civitai.com:443 "GET /api/trpc/modelVersion.donationGoals?input=%7B%22json%22:%7B%22id%22:1643268,%22authed%22:true%7D%7D HTTP/1.1" 200 None
# 2025-04-16 20:41 - INFO - Getting model 654541 version 1643268
# 2025-04-16 20:41 - INFO - Getting response from https://civitai.com/api/v1/model-versions/1643268
# 2025-04-16 20:41 - DEBUG - Starting new HTTPS connection (1): civitai.com:443
# 2025-04-16 20:41 - DEBUG - https://civitai.com:443 "GET /api/v1/model-versions/1643268 HTTP/1.1" 200 None
# 2025-04-16 20:41 - INFO - Getting model 654541 version 732302
# 2025-04-16 20:41 - INFO - Getting response from https://civitai.com/api/v1/model-versions/732302
# 2025-04-16 20:41 - DEBUG - Starting new HTTPS connection (1): civitai.com:443
# 2025-04-16 20:41 - DEBUG - https://civitai.com:443 "GET /api/v1/model-versions/732302 HTTP/1.1" 200 None
# 2025-04-16 20:41 - INFO - {
#     "model.id": 654541,
#     "model.name": "Centaur Transformation [Illustrious | Pony XL]",
#     "model.description": "<p>Lemme see those horse girls!</p><p></p><p>Prompt: <span style=\"color:#fab005\">centaur, horse legs, human torso, taur, animal ears</span></p><p></p><p>Strength: 0.7-1</p><p></p><p>If you can support me, that will also be greatly appreciated! I love making these fun LoRAs and I want to continue this.</p>",
#     "model.type": "LORA",
#     "model.nsfw": false,
#     "model.nsfwLevel": 15,
#     "model.tags": "anime, sexy, concept, centaur, woman, girls, video game, monster girl, lora, centaur girl",
#     "model.mode": null,
#     "model.creator.username": "GrimGr1m",
#     "model.creator.image": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/33cf60f6-a820-46d2-a3c3-5eb86037806f/width=96/GrimGr1m.jpeg",
#     "model.stats.downloadCount": 1145,
#     "model.stats.favoriteCount": 0,
#     "model.stats.commentCount": 1,
#     "model.stats.ratingCount": 0,
#     "model.stats.rating": 0,
#     "model.stats.thumbsUpCount": 220,
#     "model.stats.thumbsDownCount": 1,
#     "model.stats.tippedAmountCount": 1960,
#     "model.availability": "Public",
#     "model.allowNoCredit": true,
#     "model.allowCommercialUse": "Image, RentCivit, Rent, Sell",
#     "model.allowDerivatives": true,
#     "model.allowDifferentLicense": true,
#     "model.minor": false,
#     "model.poi": false,
#     "model.cosmetic": null,
#     "model.supportsGeneration": true,
#     "modelVersions": [
#         {
#             "modelVersion.id": 1643268,
#             "modelVersion.name": "Illustrious",
#             "modelVersion.description": null,
#             "modelVersion.createdAt": "2025-04-10T02:44:09.458Z",
#             "modelVersion.downloadUrl": "https://civitai.com/api/download/models/1643268",
#             "modelVersion.trainedWords": "centaur, horse legs, human torso, taur, animal ears",
#             "modelVersion.files.sizeKb": 223139.40234375,
#             "modelVersion.versionBaseModel": "Illustrious",
#             "modelVersion.versionBaseModelType": null,
#             "modelVersion.versionStatus": "Published",
#             "modelVersion.versionAvailability": "EarlyAccess",
#             "modelVersion.versionNsfwLevel": 15,
#             "modelVersion.versionFileName": "Centaur_Transformation_Illustrious.safetensors",
#             "modelVersion.versionFileType": "Model",
#             "modelVersion.updatedAt": "2025-04-10T02:49:43.948Z",
#             "modelVersion.status": "Published",
#             "modelVersion.publishedAt": "2025-04-10T02:49:43.625Z",
#             "modelVersion.trainingStatus": null,
#             "modelVersion.trainingDetails": null,
#             "modelVersion.baseModel": "Illustrious",
#             "modelVersion.baseModelType": null,
#             "modelVersion.earlyAccessEndsAt": "2025-04-25T02:49:43.625Z",
#             "modelVersion.stats.downloadCount": 10,
#             "modelVersion.stats.ratingCount": 0,
#             "modelVersion.stats.rating": 0,
#             "modelVersion.stats.thumbsUpCount": 29,
#             "model.name": "Centaur Transformation [Illustrious | Pony XL]",
#             "model.type": "LORA",
#             "images": [
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/3c62f8c3-ac5a-441c-95a1-ab00243ca80b/width=1024/69075266.jpeg",
#                     "image.nsfwLevel": 4,
#                     "image.type": "image",
#                     "image.metadata.size": 1229622,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, BREAK, full body, 1girl,     <lora:Centaur_Transformation_Illustrious:0.8> centaur, horse legs, human torso, taur, animal ears, <lora:quency_escape_queen_nikke_illustrious_goofy:0.5> quencyEq, red eyes, black hair, black bodysuit, latex, double bun, black hair, gigantic breasts,",
#                     "image.sampler": "Euler a",
#                     "image.steps": 28,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (abs, ribs:1), armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, painted nails, nude, upper body, cartoon, simple white background:1, watermark, sample watermark, (eyes,  tail, :1), blank background, simple background,"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/4c052da3-7dc2-41ca-9606-f4b5d42628a2/width=1024/69075182.jpeg",
#                     "image.nsfwLevel": 1,
#                     "image.type": "image",
#                     "image.metadata.size": 708938,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, BREAK, full body, 1girl,     <lora:Centaur_Transformation_Illustrious:0.8> centaur, horse legs, human torso, taur, animal ears, <lora:Neferpitou_2011_-_Illustrious:0.8> pitou, short hair, wavy hair, white hair, cat ears, cat tail, red eyes, blue shirt, brown shorts, socks, shoes",
#                     "image.sampler": "Euler a",
#                     "image.steps": 28,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (abs, ribs:1), armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, painted nails, nude, upper body, cartoon, simple white background:1, watermark, sample watermark, (eyes,  tail, :1), blank background, simple background,"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/ccfb14c0-d03a-45fa-9b19-75dc790a5cbe/width=1024/69075244.jpeg",
#                     "image.nsfwLevel": 2,
#                     "image.type": "image",
#                     "image.metadata.size": 1009498,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, BREAK, full body, 1girl,     <lora:Centaur_Transformation_Illustrious:0.8> centaur, horse legs, human torso, taur, animal ears, <lora:Brazilian_Miku_Hatsune_Miku_Vocaloid_Illustrious:0.8> brazilian miku, aqua hair, sunglasses on head, flower in hair, yellow shirt, brazil flag on shirt, denim shorts, booty shorts, tanned, 1girl, hatsune miku,",
#                     "image.sampler": "Euler a",
#                     "image.steps": 28,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (abs, ribs:1), armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, painted nails, nude, upper body, cartoon, simple white background:1, watermark, sample watermark, (eyes,  tail, :1), blank background, simple background,"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/f5957faf-424c-4189-9040-ade8a8e32919/width=1024/69075174.jpeg",
#                     "image.nsfwLevel": 1,
#                     "image.type": "image",
#                     "image.metadata.size": 776709,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, BREAK, full body, 1girl,     <lora:Centaur_Transformation_Illustrious:0.8> centaur, horse legs, human torso, taur, animal ears, <lora:Brazilian_Miku_Hatsune_Miku_Vocaloid_Illustrious:0.8> brazilian miku, aqua hair, sunglasses on head, flower in hair, yellow shirt, brazil flag on shirt, denim shorts, booty shorts, tanned, 1girl, hatsune miku,",
#                     "image.sampler": "Euler a",
#                     "image.steps": 28,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (abs, ribs:1), armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, painted nails, nude, upper body, cartoon, simple white background:1, watermark, sample watermark, (eyes,  tail, :1), blank background, simple background,"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/f3f33f4b-8227-42cd-8591-3d4245aad42a/width=1024/69075178.jpeg",
#                     "image.nsfwLevel": 1,
#                     "image.type": "image",
#                     "image.metadata.size": 720646,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, BREAK, full body, 1girl,     <lora:Centaur_Transformation_Illustrious:0.8> centaur, horse legs, human torso, taur, animal ears, <lora:Bottom_Heavy_Illustrious:0.8> bottom heavy, thick thighs, wide hips, huge ass, thick, gigantic ass,",
#                     "image.sampler": "Euler a",
#                     "image.steps": 28,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (abs, ribs:1), armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, painted nails, nude, upper body, cartoon, simple white background:1, watermark, sample watermark, (eyes,  tail, :1), blank background, simple background,"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/7c857f70-34ef-4025-8000-b4da32f0f42c/width=1024/69075261.jpeg",
#                     "image.nsfwLevel": 8,
#                     "image.type": "image",
#                     "image.metadata.size": 1334078,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, BREAK, full body, 1girl,     <lora:Centaur_Transformation_Illustrious:0.8> centaur, horse legs, human torso, taur, animal ears, <lora:Aloe_Interspecies_Reviewers_Illustrious:0.8> Aloe, large breasts, fairy, fairy wings, tattoos, crotch tattoos, thong, black, green hair, clothes, red panties, earrings, piercings, pygmy, small, tired, bags under eyes, small body, mini person,",
#                     "image.sampler": "Euler a",
#                     "image.steps": 28,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (abs, ribs:1), armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, painted nails, nude, upper body, cartoon, simple white background:1, watermark, sample watermark, (eyes,  tail, :1), blank background, simple background,"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/a9e50009-281a-480b-9f64-09cc09b4e498/width=1024/69075262.jpeg",
#                     "image.nsfwLevel": 4,
#                     "image.type": "image",
#                     "image.metadata.size": 1321757,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, BREAK, full body, 1girl,     <lora:Centaur_Transformation_Illustrious:0.8> centaur, horse legs, human torso, taur, animal ears, <lora:Aloe_Interspecies_Reviewers_Illustrious:0.8> Aloe, large breasts, fairy, fairy wings, tattoos, crotch tattoos, thong, black, green hair, clothes, red panties, earrings, piercings, pygmy, small, tired, bags under eyes, small body, mini person,",
#                     "image.sampler": "Euler a",
#                     "image.steps": 28,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (abs, ribs:1), armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, painted nails, nude, upper body, cartoon, simple white background:1, watermark, sample watermark, (eyes,  tail, :1), blank background, simple background,"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/7cb6b7f2-6ddf-44cc-9e11-4800adc0f511/width=1024/69075252.jpeg",
#                     "image.nsfwLevel": 1,
#                     "image.type": "image",
#                     "image.metadata.size": 1043351,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, BREAK, full body, 1girl,    <lora:Centaur_Transformation_Illustrious:0.8> centaur, horse legs, human torso, taur, animal ears <lora:Googly_Eyed_Titty_Ghost_Illustrious:0.77> tittyghost, ghost costume, breasts, googly eyes, white outfit, face covered, head covered,",
#                     "image.sampler": "Euler a",
#                     "image.steps": 28,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (abs, ribs:1), armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, painted nails, nude, upper body, cartoon, simple white background:1, watermark, sample watermark, (eyes,  tail, :1), blank background, simple background,"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/4207bbd0-86bb-4aaf-a22e-60cdd723d823/width=1024/69075186.jpeg",
#                     "image.nsfwLevel": 4,
#                     "image.type": "image",
#                     "image.metadata.size": 691560,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, BREAK, full body, 1girl,    <lora:Centaur_Transformation_Illustrious:0.8> centaur, horse legs, human torso, taur, animal ears <lora:Googly_Eyed_Titty_Ghost_Illustrious:0.77> tittyghost, ghost costume, breasts, googly eyes, white outfit, face covered, head covered,",
#                     "image.sampler": "Euler a",
#                     "image.steps": 28,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (abs, ribs:1), armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, painted nails, nude, upper body, cartoon, simple white background:1, watermark, sample watermark, (eyes,  tail, :1), blank background, simple background,"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/7b033ca5-11eb-41f8-a9f3-03c58a6a0f8c/width=1024/69075264.jpeg",
#                     "image.nsfwLevel": 8,
#                     "image.type": "image",
#                     "image.metadata.size": 1262849,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, BREAK, full body, 1girl,    <lora:Centaur_Transformation_Illustrious:0.8> centaur, horse legs, human torso, taur, animal ears <lora:Goblin_Girl_Transformation_Illustrious:0.5> GobGirl, green skin, short, long ears, large ears, colored skin, monster_girl 1girl, pointy ears, goblin, shortstack, long pointy ears,  earrings, ear piercings,",
#                     "image.sampler": "Euler a",
#                     "image.steps": 28,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (abs, ribs:1), armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, painted nails, nude, upper body, cartoon, simple white background:1, watermark, sample watermark, (eyes,  tail, :1), blank background, simple background,"
#                 }
#             ],
#             "modelVersion.GenerationCountAllTime": 46,
#             "modelVersion.DownloadCountAllTime": 10,
#             "modelVersion.RatingCountAllTime": 0,
#             "modelVersion.RatingAllTime": 0,
#             "modelVersion.ThumbsUpCountAllTime": 29,
#             "modelVersion.ThumbsDownCountAllTime": 0,
#             "modelVersion.modelId": 654541,
#             "model.downloadCountAllTime": 1145,
#             "model.favoriteCountAllTime": 0,
#             "model.thumbsUpCountAllTime": 220,
#             "model.thumbsDownCountAllTime": 1,
#             "model.commentCountAllTime": 1,
#             "model.ratingCountAllTime": 0,
#             "model.ratingAllTime": 0,
#             "model.tippedAmountCountAllTime": 1960,
#             "model.imageCountAllTime": 0,
#             "model.collectedCountAllTime": 101,
#             "model.generationCountAllTime": 33479,
#             "model.earlyAccessDeadlineModel": "2025-04-25T02:49:43.625Z",
#             "modelVersion.earlyAccessDeadline": "2025-04-25T02:49:43.625Z",
#             "modelVersion.donationGoalAmount": 10000,
#             "modelVersion.donationGoalTotal": 1910,
#             "modelVersion.earlyAccessConfig.timeframe": 15,
#             "modelVersion.earlyAccessConfig.donationGoal": 10000,
#             "modelVersion.earlyAccessConfig.downloadPrice": 200,
#             "modelVersion.earlyAccessConfig.donationGoalId": 9064,
#             "modelVersion.earlyAccessConfig.generationPrice": 50,
#             "modelVersion.earlyAccessConfig.chargeForDownload": true,
#             "modelVersion.earlyAccessConfig.originalTimeframe": null,
#             "modelVersion.earlyAccessConfig.chargeForGeneration": true,
#             "modelVersion.earlyAccessConfig.donationGoalEnabled": true,
#             "modelVersion.earlyAccessConfig.originalPublishedAt": "2025-04-10T02:49:43.625Z",
#             "modelVersion.earlyAccessConfig.generationTrialLimit": 10
#         },
#         {
#             "modelVersion.id": 732302,
#             "modelVersion.name": "Pony",
#             "modelVersion.description": null,
#             "modelVersion.createdAt": "2024-08-17T06:45:13.780Z",
#             "modelVersion.downloadUrl": "https://civitai.com/api/download/models/732302",
#             "modelVersion.trainedWords": "centaur, horse legs, human torso, taur, animal ears",
#             "modelVersion.files.sizeKb": 445805.32421875,
#             "modelVersion.versionBaseModel": "Pony",
#             "modelVersion.versionBaseModelType": null,
#             "modelVersion.versionStatus": "Published",
#             "modelVersion.versionAvailability": "Public",
#             "modelVersion.versionNsfwLevel": 7,
#             "modelVersion.versionFileName": "Centaur_Girl.safetensors",
#             "modelVersion.versionFileType": "Model",
#             "modelVersion.updatedAt": "2025-04-10T02:44:09.458Z",
#             "modelVersion.status": "Published",
#             "modelVersion.publishedAt": "2024-08-17T12:55:07.307Z",
#             "modelVersion.trainingStatus": null,
#             "modelVersion.trainingDetails": null,
#             "modelVersion.baseModel": "Pony",
#             "modelVersion.baseModelType": null,
#             "modelVersion.earlyAccessEndsAt": null,
#             "modelVersion.stats.downloadCount": 1135,
#             "modelVersion.stats.ratingCount": 0,
#             "modelVersion.stats.rating": 0,
#             "modelVersion.stats.thumbsUpCount": 202,
#             "model.name": "Centaur Transformation [Illustrious | Pony XL]",
#             "model.type": "LORA",
#             "images": [
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/9fcb8d93-431c-4a4d-9b36-e0172aa83321/width=1024/24717276.jpeg",
#                     "image.nsfwLevel": 1,
#                     "image.type": "image",
#                     "image.metadata.size": 2035811,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, full body,  <lora:Centaur_Girl:0.8> centaur, , horse legs, human torso, taur, animal ears",
#                     "image.sampler": "Euler a",
#                     "image.steps": 35,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (score_4, score_5, score_6, monochrome, (censor), 3d, realistic, render, CGI, text, watermark, cartoon, sketch, greyscale:1),, armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, nude, painted nails, white background, simple background, legs"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/67d50010-79a1-4571-a520-7c91f0ff2a22/width=1024/24717270.jpeg",
#                     "image.nsfwLevel": 1,
#                     "image.type": "image",
#                     "image.metadata.size": 1813042,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, full body,  <lora:Centaur_Girl:0.8> centaur, , horse legs, human torso, taur, animal ears <lora:EPpkJessiePony:1> EPpkJessie",
#                     "image.sampler": "Euler a",
#                     "image.steps": 35,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (score_4, score_5, score_6, monochrome, (censor), 3d, realistic, render, CGI, text, watermark, cartoon, sketch, greyscale:1),, armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, nude, painted nails, white background, simple background, legs"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/eccea09f-7bc9-4f1e-b036-908bb06f24ce/width=1024/24717252.jpeg",
#                     "image.nsfwLevel": 2,
#                     "image.type": "image",
#                     "image.metadata.size": 1274980,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, full body,  <lora:Centaur_Girl:0.8> centaur, , horse legs, human torso, taur, animal ears <lora:EPpkJessiePony:1> EPpkJessie",
#                     "image.sampler": "Euler a",
#                     "image.steps": 35,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (score_4, score_5, score_6, monochrome, (censor), 3d, realistic, render, CGI, text, watermark, cartoon, sketch, greyscale:1),, armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, nude, painted nails, white background, simple background, legs"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/660e6855-7bd5-493e-900f-84f710f6d99c/width=1024/24717275.jpeg",
#                     "image.nsfwLevel": 2,
#                     "image.type": "image",
#                     "image.metadata.size": 2033003,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, full body,  <lora:Centaur_Girl:0.8> centaur, , horse legs, human torso, taur, animal ears <lora:Yaomomo:0.9> yaomomo, woman, person",
#                     "image.sampler": "Euler a",
#                     "image.steps": 35,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (score_4, score_5, score_6, monochrome, (censor), 3d, realistic, render, CGI, text, watermark, cartoon, sketch, greyscale:1),, armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, nude, painted nails, white background, simple background, legs"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/05928157-529c-480f-aed6-f73fe17fc1a2/width=1024/24717261.jpeg",
#                     "image.nsfwLevel": 2,
#                     "image.type": "image",
#                     "image.metadata.size": 1603265,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, full body,  <lora:Centaur_Girl:0.8> centaur, , horse legs, human torso, taur, animal ears <lora:Amethyst_SDXL:0.9> hair over one eye, amethyst, colored skin, purple skin, long hair, 1girl",
#                     "image.sampler": "Euler a",
#                     "image.steps": 35,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (score_4, score_5, score_6, monochrome, (censor), 3d, realistic, render, CGI, text, watermark, cartoon, sketch, greyscale:1),, armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, nude, painted nails, white background, simple background, legs"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/d5bde7f7-0227-4101-8449-9d6a8c82738b/width=1024/24717277.jpeg",
#                     "image.nsfwLevel": 1,
#                     "image.type": "image",
#                     "image.metadata.size": 946210,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, full body,  <lora:Centaur_Girl:0.8> centaur, , horse legs, human torso, taur, animal ears <lora:Hinata_Sakeguchi_Tensura:0.9> Sakeguchi_Hinata, black hair, asian, short hair, purple eyes, 1girl, tall, slender, hinata Sakeguchi, large breasts, adult,",
#                     "image.sampler": "Euler a",
#                     "image.steps": 35,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (score_4, score_5, score_6, monochrome, (censor), 3d, realistic, render, CGI, text, watermark, cartoon, sketch, greyscale:1),, armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, nude, painted nails, white background, simple background, legs"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/f63408ba-6ee5-4b09-b459-f458bb00f36d/width=1024/24717284.jpeg",
#                     "image.nsfwLevel": 2,
#                     "image.type": "image",
#                     "image.metadata.size": 850850,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, full body,  <lora:Centaur_Girl:0.8> centaur, , horse legs, human torso, taur, animal ears <lora:Hinata_Sakeguchi_Tensura:0.9> Sakeguchi_Hinata, black hair, asian, short hair, purple eyes, 1girl, tall, slender, hinata Sakeguchi, large breasts, adult,",
#                     "image.sampler": "Euler a",
#                     "image.steps": 35,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (score_4, score_5, score_6, monochrome, (censor), 3d, realistic, render, CGI, text, watermark, cartoon, sketch, greyscale:1),, armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, nude, painted nails, white background, simple background, legs"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/08c0ef15-9854-41a6-968d-156f6cd0b71b/width=1024/24717297.jpeg",
#                     "image.nsfwLevel": 4,
#                     "image.type": "image",
#                     "image.metadata.size": 2056983,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, full body,  <lora:Centaur_Girl:0.8> centaur, , horse legs, human torso, taur, animal ears",
#                     "image.sampler": "Euler a",
#                     "image.steps": 35,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (score_4, score_5, score_6, monochrome, (censor), 3d, realistic, render, CGI, text, watermark, cartoon, sketch, greyscale:1),, armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, nude, painted nails, white background, simple background, legs"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/eead5240-d1f9-48a3-867a-be0bfca7eeb8/width=1024/24718294.jpeg",
#                     "image.nsfwLevel": 2,
#                     "image.type": "image",
#                     "image.metadata.size": 863627,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, full body,  <lora:Centaur_Girl:0.8> centaur, , horse legs, human torso, taur, animal ears <lora:Hoseki_UzakiChan_YanagiUzaki_PDXL_v1:0.9> ynguzk, fang, covered eyes, short hair with long locks, pink shirt, long sleeves, blue shorts",
#                     "image.sampler": "Euler a",
#                     "image.steps": 35,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (score_4, score_5, score_6, monochrome, (censor), 3d, realistic, render, CGI, text, watermark, cartoon, sketch, greyscale:1),, armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, nude, painted nails, white background, simple background, legs"
#                 },
#                 {
#                     "image.url": "https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/375fc8dd-ed3d-4e90-8f57-5ce0ad80e384/width=1024/24718317.jpeg",
#                     "image.nsfwLevel": 2,
#                     "image.type": "image",
#                     "image.metadata.size": 2080527,
#                     "image.prompt": "score_9, score_8_up, score_7_up, score_6_up, score_5_up, score_4_up, masterpiece, high quality, full body,  <lora:Centaur_Girl:0.8> centaur, , horse legs, human torso, taur, animal ears <lora:albedo_official:0.3> albedo, albedo (overlord)",
#                     "image.sampler": "Euler a",
#                     "image.steps": 35,
#                     "image.cfgScale": 7,
#                     "image.negativePrompt": "bad anatomy, moles on face, many moles, multiple fingers, deformed hands, nipples, deformed panties, (score_4, score_5, score_6, monochrome, (censor), 3d, realistic, render, CGI, text, watermark, cartoon, sketch, greyscale:1),, armor, bow, 1 volleyball, mutilated, deformed hands, extra digits, extra legs, extra limbs, disembodied limbs, black pubic hair, nude, deformed, multiple feet, multiple legs, nude, painted nails, white background, simple background, legs"
#                 }
#             ],
#             "modelVersion.GenerationCountAllTime": 33433,
#             "modelVersion.DownloadCountAllTime": 1135,
#             "modelVersion.RatingCountAllTime": 0,
#             "modelVersion.RatingAllTime": 0,
#             "modelVersion.ThumbsUpCountAllTime": 202,
#             "modelVersion.ThumbsDownCountAllTime": 1,
#             "modelVersion.modelId": 654541,
#             "model.downloadCountAllTime": 1145,
#             "model.favoriteCountAllTime": 0,
#             "model.thumbsUpCountAllTime": 220,
#             "model.thumbsDownCountAllTime": 1,
#             "model.commentCountAllTime": 1,
#             "model.ratingCountAllTime": 0,
#             "model.ratingAllTime": 0,
#             "model.tippedAmountCountAllTime": 1960,
#             "model.imageCountAllTime": 0,
#             "model.collectedCountAllTime": 101,
#             "model.generationCountAllTime": 33479,
#             "model.earlyAccessDeadlineModel": "2025-04-25T02:49:43.625Z",
#             "modelVersion.earlyAccessDeadline": null,
#             "modelVersion.donationGoalAmount": null,
#             "modelVersion.donationGoalTotal": null
#         }
#     ]
# }
